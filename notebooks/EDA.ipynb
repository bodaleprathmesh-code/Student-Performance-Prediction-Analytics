# %% [markdown]
# # Exploratory Data Analysis (EDA) for the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
df = pd.read_csv("student_performance_dataset1_corrected.csv")

print("Dataset loaded successfully!")
print("Shape:", df.shape)
# Out:
# Dataset loaded successfully!
# Shape: (5000, 12)

# %%
df.head()
# Out:
#    Student_ID  Gender  Study_Hours  Attendance_Percent  Previous_Marks  \
# 0        1001  Female          6.2                  85              75
# 1        1002    Male          7.9                  65              70
# 2        1003    Male          7.0                  84              88
# 3        1004  Female          6.5                  90              58
# 4        1005    Male          9.3                  98              82
#
#    Assignment_Score  Quiz_Score  Internal_Marks Internet_Access  \
# 0                75          67              28             Yes
# 1                61          32              21             Yes
# 2                66          53              23             Yes
# 3                73          68              19             Yes
# 4                81          65              26             Yes
#
#   Extracurricular  Sleep_Hours  Final_Marks
# 0             Yes          6.9           78
# 1             Yes          7.9           64
# ...

# %%
df.tail()
# Out:
#       Student_ID  Gender  Study_Hours  Attendance_Percent  Previous_Marks  \
# 4995        5996    Male          1.6                  88              54
# 4996        5997    Male          8.9                  84              45
# 4997        5998  Female          4.3                  70              73
# 4998        5999  Female          3.5                  80              65
# 4999        6000    Male          7.6                  69              69
#
#       Assignment_Score  Quiz_Score  Internal_Marks Internet_Access  \
# 4995                43          43              16              No
# 4996                75          52              16             Yes
# 4997                64          86              26             Yes
# 4998                88          80              21              No
# 4999                67          80              17             Yes
#
#      Extracurricular  Sleep_Hours  Final_Marks
# 4995              No          7.7           51
# ...

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 5000
# Columns: 12

# %%
print("Dataset Columns:")
print(df.columns.tolist())
# Out:
# Dataset Columns:
# ['Student_ID', 'Gender', 'Study_Hours', 'Attendance_Percent', 'Previous_Marks', 'Assignment_Score', 'Quiz_Score', 'Internal_Marks', 'Internet_Access', 'Extracurricular', 'Sleep_Hours', 'Final_Marks']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Student_ID          5000 non-null   int64
#  1   Gender              5000 non-null   object
#  2   Study_Hours         5000 non-null   float64
#  3   Attendance_Percent  5000 non-null   int64
#  4   Previous_Marks      5000 non-null   int64
#  5   Assignment_Score    5000 non-null   int64
#  6   Quiz_Score          5000 non-null   int64
#  7   Internal_Marks      5000 non-null   int64
#  8   Internet_Access     5000 non-null   object
#  9   Extracurricular     5000 non-null   object
#  10  Sleep_Hours         5000 non-null   float64
#  11  Final_Marks         5000 non-null   int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 468.9+ KB

# %%
df.describe()
# Out:
#         Student_ID  Study_Hours  Attendance_Percent  Previous_Marks  \
# count  5000.000000   5000.00000         5000.000000     5000.000000
# mean   3500.500000      5.78850           78.663800       66.867400
# std    1443.520003      2.31309           12.201678       15.470219
# min    1001.000000      1.00000           50.000000       30.000000
# 25%    2250.750000      4.00000           70.000000       56.000000
# 50%    3500.500000      6.20000           81.000000       69.000000
# 75%    4750.250000      7.50000           88.000000       79.000000
# max    6000.000000     10.00000          100.000000       95.000000
#
#        Assignment_Score   Quiz_Score  Internal_Marks  Sleep_Hours  Final_Marks
# count       5000.000000  5000.000000     5000.000000   5000.00000  5000.000000
# mean          71.959200    68.892000       21.237400      6.43854    68.236000
# std           14.899877    17.089012        4.908346      0.94862     7.555298
# ...

# %%
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Student_ID            0
# Gender                0
# Study_Hours           0
# Attendance_Percent    0
# Previous_Marks        0
# Assignment_Score      0
# Quiz_Score            0
# Internal_Marks        0
# Internet_Access       0
# Extracurricular       0
# Sleep_Hours           0
# Final_Marks           0
# dtype: int64

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
print(df["Gender"].value_counts())
# Out:
# Gender
# Male      2750
# Female    2250
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))

sns.countplot(data=df, x="Gender")

plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Number of Students")

plt.tight_layout()

plt.savefig(
    "../images/gender_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
import os

print("Current notebook folder:")
print(os.getcwd())

print("\nImages folder:")
print(os.path.abspath("../images"))

print("\nImages folder exists:", os.path.exists("../images"))
# Out:
# Current notebook folder:
# D:\StudentsPredictionsMarksProject\notebooks
#
# Images folder:
# D:\StudentsPredictionsMarksProject\images
#
# Images folder exists: True

# %%
print(df["Internet_Access"].value_counts())
# Out:
# Internet_Access
# Yes    4391
# No      609
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))

sns.countplot(data=df, x="Internet_Access")

plt.title("Internet Access Distribution")
plt.xlabel("Internet Access")
plt.ylabel("Number of Students")

plt.tight_layout()

plt.savefig(
    "../images/internet_access_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
print(df["Extracurricular"].value_counts())
# Out:
# Extracurricular
# Yes    2767
# No     2233
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))

sns.countplot(data=df, x="Extracurricular")

plt.title("Extracurricular Activity Distribution")
plt.xlabel("Extracurricular Activity")
plt.ylabel("Number of Students")

plt.tight_layout()

plt.savefig(
    "../images/extracurricular_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(7, 4))

sns.histplot(
    data=df,
    x="Study_Hours",
    kde=True
)

plt.title("Study Hours Distribution")
plt.xlabel("Study Hours")
plt.ylabel("Number of Students")

plt.tight_layout()

plt.savefig(
    "../images/study_hours_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(7, 4))

sns.histplot(
    data=df,
    x="Attendance_Percent",
    kde=True
)

plt.title("Attendance Distribution")
plt.xlabel("Attendance (%)")
plt.ylabel("Number of Students")

plt.tight_layout()

plt.savefig(
    "../images/attendance_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(7, 4))

sns.histplot(
    data=df,
    x="Previous_Marks",
    kde=True
)

plt.title("Previous Marks Distribution")
plt.xlabel("Previous Marks")
plt.ylabel("Number of Students")

plt.tight_layout()

plt.savefig(
    "../images/previous_marks_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(7, 4))

sns.histplot(
    data=df,
    x="Assignment_Score",
    kde=True
)

plt.title("Assignment Score Distribution")
plt.xlabel("Assignment Score")
plt.ylabel("Number of Students")

plt.tight_layout()

plt.savefig(
    "../images/assignment_score_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(7, 4))

sns.histplot(
    data=df,
    x="Quiz_Score",
    kde=True
)

plt.title("Quiz Score Distribution")
plt.xlabel("Quiz Score")
plt.ylabel("Number of Students")

plt.tight_layout()

plt.savefig(
    "../images/quiz_score_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(7, 4))

sns.histplot(
    data=df,
    x="Internal_Marks",
    kde=True
)

plt.title("Internal Marks Distribution")
plt.xlabel("Internal Marks")
plt.ylabel("Number of Students")

plt.tight_layout()

plt.savefig(
    "../images/internal_marks_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(7, 4))

sns.histplot(
    data=df,
    x="Sleep_Hours",
    kde=True
)

plt.title("Sleep Hours Distribution")
plt.xlabel("Sleep Hours")
plt.ylabel("Number of Students")

plt.tight_layout()

plt.savefig(
    "../images/sleep_hours_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.histplot(
    data=df,
    x="Final_Marks",
    kde=True
)

plt.title("Final Marks Distribution")
plt.xlabel("Final Marks")
plt.ylabel("Number of Students")

plt.tight_layout()

plt.savefig(
    "../images/final_marks_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
print("Final Marks Statistics")
print("----------------------")

print("Minimum :", df["Final_Marks"].min())
print("Maximum :", df["Final_Marks"].max())
print("Mean    :", round(df["Final_Marks"].mean(), 2))
print("Median  :", df["Final_Marks"].median())
print("Std Dev :", round(df["Final_Marks"].std(), 2))
# Out:
# Final Marks Statistics
# ----------------------
# Minimum : 42
# Maximum : 92
# Mean    : 68.24
# Median  : 68.0
# Std Dev : 7.56

# %%
numerical_columns = df.select_dtypes(
    include=["int64", "float64"]
).columns.tolist()

print("Numerical Columns:")
print(numerical_columns)
# Out:
# Numerical Columns:
# ['Student_ID', 'Study_Hours', 'Attendance_Percent', 'Previous_Marks', 'Assignment_Score', 'Quiz_Score', 'Internal_Marks', 'Sleep_Hours', 'Final_Marks']

# %%
plt.figure(figsize=(12, 6))

sns.boxplot(
    data=df[numerical_columns]
)

plt.title("Boxplot of Numerical Features")
plt.xticks(rotation=45)

plt.tight_layout()

plt.savefig(
    "../images/numerical_features_boxplot.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
# Calculate outliers using IQR method

outlier_summary = []

for column in numerical_columns:
    
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    
    IQR = Q3 - Q1
    
    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR
    
    outliers = df[
        (df[column] < lower_limit) |
        (df[column] > upper_limit)
    ]
    
    outlier_summary.append([
        column,
        len(outliers)
    ])

outlier_df = pd.DataFrame(
    outlier_summary,
    columns=["Feature", "Outlier_Count"]
)

outlier_df
# Out:
#               Feature  Outlier_Count
# 0          Student_ID              0
# 1         Study_Hours              0
# 2  Attendance_Percent              0
# 3      Previous_Marks              0
# 4    Assignment_Score              0
# 5          Quiz_Score              0
# 6      Internal_Marks              0
# 7         Sleep_Hours              0
# 8         Final_Marks             31

# %%
# Calculate correlation matrix for numerical features

correlation_matrix = df[numerical_columns].corr()

correlation_matrix
# Out:
#                     Student_ID  Study_Hours  Attendance_Percent  \
# Student_ID            1.000000    -0.026846            0.001288
# Study_Hours          -0.026846     1.000000           -0.002748
# Attendance_Percent    0.001288    -0.002748            1.000000
# Previous_Marks       -0.005667     0.003355           -0.000524
# Assignment_Score      0.027186     0.007385            0.013380
# Quiz_Score           -0.015089     0.003152           -0.002893
# Internal_Marks       -0.004006    -0.016309           -0.021056
# Sleep_Hours          -0.011752    -0.010195            0.011503
# Final_Marks          -0.023323     0.332586            0.166285
#
#                     Previous_Marks  Assignment_Score  Quiz_Score  \
# Student_ID               -0.005667          0.027186   -0.015089
# Study_Hours               0.003355          0.007385    0.003152
# Attendance_Percent       -0.000524          0.013380   -0.002893
# ...

# %%
plt.figure(figsize=(12, 8))

sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5
)

plt.title("Correlation Heatmap of Numerical Features")

plt.tight_layout()

plt.savefig(
    "../images/correlation_heatmap.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
# Correlation of each numerical feature with Final Marks

final_marks_correlation = (
    df[numerical_columns]
    .corr()["Final_Marks"]
    .sort_values(ascending=False)
)

print("Correlation with Final Marks:")
print(final_marks_correlation)
# Out:
# Correlation with Final Marks:
# Final_Marks           1.000000
# Previous_Marks        0.579297
# Internal_Marks        0.394626
# Study_Hours           0.332586
# Quiz_Score            0.327030
# Assignment_Score      0.308328
# Attendance_Percent    0.166285
# Sleep_Hours           0.111002
# Student_ID           -0.023323
# Name: Final_Marks, dtype: float64

# %%
# Remove Final_Marks itself from the correlation chart

feature_correlation = final_marks_correlation.drop("Final_Marks")

plt.figure(figsize=(9, 5))

feature_correlation.sort_values().plot(
    kind="barh"
)

plt.title("Feature Correlation with Final Marks")
plt.xlabel("Correlation")
plt.ylabel("Features")

plt.tight_layout()

plt.savefig(
    "../images/feature_correlation_with_final_marks.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(7, 5))

sns.scatterplot(
    data=df,
    x="Previous_Marks",
    y="Final_Marks",
    alpha=0.6
)

plt.title("Previous Marks vs Final Marks")
plt.xlabel("Previous Marks")
plt.ylabel("Final Marks")

plt.tight_layout()

plt.savefig(
    "../images/previous_marks_vs_final_marks.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(7, 5))

sns.scatterplot(
    data=df,
    x="Study_Hours",
    y="Final_Marks",
    alpha=0.6
)

sns.regplot(
    data=df,
    x="Study_Hours",
    y="Final_Marks",
    scatter=False
)

plt.title("Study Hours vs Final Marks")
plt.xlabel("Study Hours")
plt.ylabel("Final Marks")

plt.tight_layout()

plt.savefig(
    "../images/study_hours_vs_final_marks.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(7, 5))

sns.scatterplot(
    data=df,
    x="Internal_Marks",
    y="Final_Marks",
    alpha=0.6
)

sns.regplot(
    data=df,
    x="Internal_Marks",
    y="Final_Marks",
    scatter=False
)

plt.title("Internal Marks vs Final Marks")
plt.xlabel("Internal Marks")
plt.ylabel("Final Marks")

plt.tight_layout()

plt.savefig(
    "../images/internal_marks_vs_final_marks.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(7, 5))

sns.scatterplot(
    data=df,
    x="Quiz_Score",
    y="Final_Marks",
    alpha=0.6
)

sns.regplot(
    data=df,
    x="Quiz_Score",
    y="Final_Marks",
    scatter=False
)

plt.title("Quiz Score vs Final Marks")
plt.xlabel("Quiz Score")
plt.ylabel("Final Marks")

plt.tight_layout()

plt.savefig(
    "../images/quiz_score_vs_final_marks.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(7, 5))

sns.scatterplot(
    data=df,
    x="Assignment_Score",
    y="Final_Marks",
    alpha=0.6
)

sns.regplot(
    data=df,
    x="Assignment_Score",
    y="Final_Marks",
    scatter=False
)

plt.title("Assignment Score vs Final Marks")
plt.xlabel("Assignment Score")
plt.ylabel("Final Marks")

plt.tight_layout()

plt.savefig(
    "../images/assignment_score_vs_final_marks.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(7, 5))

sns.scatterplot(
    data=df,
    x="Attendance_Percent",
    y="Final_Marks",
    alpha=0.6
)

sns.regplot(
    data=df,
    x="Attendance_Percent",
    y="Final_Marks",
    scatter=False
)

plt.title("Attendance vs Final Marks")
plt.xlabel("Attendance (%)")
plt.ylabel("Final Marks")

plt.tight_layout()

plt.savefig(
    "../images/attendance_vs_final_marks.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(7, 5))

sns.scatterplot(
    data=df,
    x="Sleep_Hours",
    y="Final_Marks",
    alpha=0.6
)

sns.regplot(
    data=df,
    x="Sleep_Hours",
    y="Final_Marks",
    scatter=False
)

plt.title("Sleep Hours vs Final Marks")
plt.xlabel("Sleep Hours")
plt.ylabel("Final Marks")

plt.tight_layout()

plt.savefig(
    "../images/sleep_hours_vs_final_marks.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(7, 5))

sns.boxplot(
    data=df,
    x="Gender",
    y="Final_Marks"
)

plt.title("Gender vs Final Marks")
plt.xlabel("Gender")
plt.ylabel("Final Marks")

plt.tight_layout()

plt.savefig(
    "../images/gender_vs_final_marks.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(7, 5))

sns.boxplot(
    data=df,
    x="Extracurricular",
    y="Final_Marks"
)

plt.title("Extracurricular Activity vs Final Marks")
plt.xlabel("Extracurricular Activity")
plt.ylabel("Final Marks")

plt.tight_layout()

plt.savefig(
    "../images/extracurricular_vs_final_marks.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
print("Average Final Marks by Gender")
print("--------------------------------")

print(
    df.groupby("Gender")["Final_Marks"]
      .agg(["mean", "median", "count"])
      .round(2)
)
# Out:
# Average Final Marks by Gender
# --------------------------------
#          mean  median  count
# Gender
# Female  68.24    68.0   2250
# Male    68.23    68.0   2750

# %%
print("Average Final Marks by Internet Access")
print("---------------------------------------")

print(
    df.groupby("Internet_Access")["Final_Marks"]
      .agg(["mean", "median", "count"])
      .round(2)
)
# Out:
# Average Final Marks by Internet Access
# ---------------------------------------
#                   mean  median  count
# Internet_Access
# No               68.26    68.0    609
# Yes              68.23    69.0   4391

# %%
print("Average Final Marks by Extracurricular Activity")
print("-----------------------------------------------")

print(
    df.groupby("Extracurricular")["Final_Marks"]
      .agg(["mean", "median", "count"])
      .round(2)
)
# Out:
# Average Final Marks by Extracurricular Activity
# -----------------------------------------------
#                   mean  median  count
# Extracurricular
# No               68.21    69.0   2233
# Yes              68.26    68.0   2767

# %%
# Create a summary of feature relationships with Final Marks

correlation_summary = pd.DataFrame({
    "Feature": feature_correlation.index,
    "Correlation_with_Final_Marks": feature_correlation.values
})

correlation_summary["Absolute_Correlation"] = (
    correlation_summary["Correlation_with_Final_Marks"].abs()
)

correlation_summary = correlation_summary.sort_values(
    by="Absolute_Correlation",
    ascending=False
).reset_index(drop=True)

correlation_summary
# Out:
#               Feature  Correlation_with_Final_Marks  Absolute_Correlation
# 0      Previous_Marks                      0.579297              0.579297
# 1      Internal_Marks                      0.394626              0.394626
# 2         Study_Hours                      0.332586              0.332586
# 3          Quiz_Score                      0.327030              0.327030
# 4    Assignment_Score                      0.308328              0.308328
# 5  Attendance_Percent                      0.166285              0.166285
# 6         Sleep_Hours                      0.111002              0.111002
# 7          Student_ID                     -0.023323              0.023323

# %%
# Remove Student_ID because it is only an identifier

df_model = df.drop(columns=["Student_ID"])

print("Original Dataset Shape :", df.shape)
print("ML Dataset Shape       :", df_model.shape)

print("\nRemaining Columns:")
print(df_model.columns.tolist())
# Out:
# Original Dataset Shape : (5000, 12)
# ML Dataset Shape       : (5000, 11)
#
# Remaining Columns:
# ['Gender', 'Study_Hours', 'Attendance_Percent', 'Previous_Marks', 'Assignment_Score', 'Quiz_Score', 'Internal_Marks', 'Internet_Access', 'Extracurricular', 'Sleep_Hours', 'Final_Marks']

# %%
# Separate features and target

X = df_model.drop(columns=["Final_Marks"])
y = df_model["Final_Marks"]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (5000, 10)
# y shape: (5000,)

# %%
# Identify numerical features

numerical_features = X.select_dtypes(
    include=["int64", "float64"]
).columns.tolist()

print("Numerical Features:")
print(numerical_features)
# Out:
# Numerical Features:
# ['Study_Hours', 'Attendance_Percent', 'Previous_Marks', 'Assignment_Score', 'Quiz_Score', 'Internal_Marks', 'Sleep_Hours']

# %%
# Identify categorical features

categorical_features = X.select_dtypes(
    include=["object"]
).columns.tolist()

print("\nCategorical Features:")
print(categorical_features)
# Out:
# Categorical Features:
# ['Gender', 'Internet_Access', 'Extracurricular']

# %%
print("Final Features for Machine Learning")
print("-----------------------------------")

for i, feature in enumerate(X.columns, start=1):
    print(f"{i}. {feature}")

print("\nTarget:")
print("Final_Marks")
# Out:
# Final Features for Machine Learning
# -----------------------------------
# 1. Gender
# 2. Study_Hours
# 3. Attendance_Percent
# 4. Previous_Marks
# 5. Assignment_Score
# 6. Quiz_Score
# 7. Internal_Marks
# 8. Internet_Access
# 9. Extracurricular
# 10. Sleep_Hours
#
# Target:
# Final_Marks

# %%
# ... All your EDA, Data Cleaning, and Model Training code ...

# Train your model
model.fit(X_train, y_train)

# -------------------------------------------------------------
# ADD THE SIMULATION CODE HERE (AT THE VERY END OF THE FILE)
# -------------------------------------------------------------
sample_student = X_test.iloc[[0]].copy()
print(f"Original Prediction: {model.predict(sample_student)[0]:.2f}")

# Simulating more sleep
sample_student["Sleep_Hours"] += 2.0
print(f"New Prediction with +2 hrs sleep: {model.predict(sample_student)[0]:.2f}")
